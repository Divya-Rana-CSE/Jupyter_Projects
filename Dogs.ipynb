# %% [markdown]
# # Creating Data frame using csv file

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dogs.csv")
# df.head()
df.tail()
# Out:
#                       Unnamed: 0 Dog Breed Group  \
# 387  Wirehaired Pointing Griffon   Sporting Dogs
# 388               Xoloitzcuintli  Companion Dogs
# 389               Yakutian Laika    Working Dogs
# 390                     Yorkipoo     Hybrid Dogs
# 391            Yorkshire Terrier  Companion Dogs
#
#                                                 Height           Weight  \
# 387               20 to 24 inches tall at the shoulder  50 to 60 pounds
# 388  1 foot, 6 inches to 1 foot, 11 inches tall at ...  10 to 50 pounds
# 389                                    20 to 23 inches  40 to 55 pounds
# 390                7 to 15 inches tall at the shoulder   3 to 14 pounds
# 391                 8 to 9 inches tall at the shoulder    4 to 6 pounds
#
#           Life Span  Adaptability  Adapts Well To Apartment Living  \
# 387  10 to 14 years           NaN                                1
# 388  14 to 20 years           NaN                                5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 37 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       392 non-null    object
#  1   Dog Breed Group                  392 non-null    object
#  2   Height                           389 non-null    object
#  3   Weight                           385 non-null    object
#  4   Life Span                        392 non-null    object
#  5   Adaptability                     0 non-null      float64
#  6   Adapts Well To Apartment Living  392 non-null    int64
#  7   Good For Novice Owners           392 non-null    int64
#  8   Sensitivity Level                392 non-null    int64
#  9   Tolerates Being Alone            392 non-null    int64
#  10  Tolerates Cold Weather           392 non-null    int64
#  11  Tolerates Hot Weather            392 non-null    int64
# ...

# %%
df.describe()
# Out:
#        Adaptability  Adapts Well To Apartment Living  Good For Novice Owners  \
# count           0.0                       392.000000              392.000000
# mean            NaN                         2.989796                2.790816
# std             NaN                         1.479579                1.176112
# min             NaN                         1.000000                1.000000
# 25%             NaN                         2.000000                2.000000
# 50%             NaN                         3.000000                3.000000
# 75%             NaN                         4.000000                4.000000
# max             NaN                         5.000000                5.000000
#
#        Sensitivity Level  Tolerates Being Alone  Tolerates Cold Weather  \
# count         392.000000             392.000000              392.000000
# mean            3.673469               2.084184                3.295918
# ...

# %% [markdown]
# # slicing DataFrame

# %%
df1= df.loc[:,['Dog Breed Group','Life Span' , 'Height','Weight']]
df1.head()
# Out:
#     Dog Breed Group       Life Span                                Height  \
# 0  Mixed Breed Dogs  10 to 12 years                       20 to 29 inches
# 1  Mixed Breed Dogs  13 to 18 years                        6 to 12 inches
# 2    Companion Dogs  12 to 14 years   9 to 11 inches tall at the shoulder
# 3        Hound Dogs  10 to 12 years  24 to 26 inches tall at the shoulder
# 4      Terrier Dogs  10 to 13 years  21 to 23 inches tall at the shoulder
#
#             Weight
# 0  50 to 75 pounds
# 1   4 to 12 pounds
# 2    7 to 9 pounds
# 3  50 to 60 pounds
# 4  40 to 65 pounds

# %%
# dogs.sort_values(["weight_kg","height_cm"])

# %%
df2=df1.sort_values("Dog Breed Group")
df2.head(50)
# Out:
#     Dog Breed Group           Life Span  \
# 391  Companion Dogs      12 to 15 years
# 341  Companion Dogs      12 to 16 years
# 57   Companion Dogs      12 to 15 years
# 333  Companion Dogs      13 to 15 years
# 69   Companion Dogs      12 to 14 years
# 79   Companion Dogs      13 to 15 years
# 314  Companion Dogs      12 to 15 years
# 308  Companion Dogs      12 to 15 years
# 92   Companion Dogs     8 to 12 years.
# 93   Companion Dogs      12 to 15 years
# 100  Companion Dogs       8 to 12 years
# 293  Companion Dogs      12 to 15 years
# 114  Companion Dogs       9 to 15 years
# 289  Companion Dogs      12 to 16 years
# 124  Companion Dogs      10 to 18 years
# 126  Companion Dogs      10 to 14 years
# 271  Companion Dogs      10 to 14 years
# 264  Companion Dogs      12 to 15 years
# 182  Companion Dogs      11 to 14 years
# 175  Companion Dogs      12 to 14 years
# 172  Companion Dogs      10 to 12 years
# 216  Companion Dogs      12 to 15 years
# ...

# %%
df3=df.sort_values("Easy To Groom")
df3.head(30)
# Out:
#                   Unnamed: 0   Dog Breed Group  \
# 261               Lhasa Apso    Companion Dogs
# 307                  Poochon  Mixed Breed Dogs
# 153                   Daniff  Mixed Breed Dogs
# 237         Korean Jindo Dog     Sporting Dogs
# 302                  Pomapoo  Mixed Breed Dogs
# 30       Australian Shepherd      Herding Dogs
# 301  Polish Lowland Sheepdog      Herding Dogs
# 293                Pekingese    Companion Dogs
# 37                    Barbet     Sporting Dogs
# 308                   Poodle    Companion Dogs
# 287     Old English Sheepdog      Herding Dogs
# 216                 Havanese    Companion Dogs
# 217                  Havapoo  Mixed Breed Dogs
# 218                 Hokkaido      Working Dogs
# 48        Bedlington Terrier      Terrier Dogs
# 221                  Huskita  Mixed Breed Dogs
# 257        Lagotto Romagnolo     Sporting Dogs
# 62                Bloodhound        Hound Dogs
# 224       Icelandic Sheepdog      Herding Dogs
# ...

# %%
easy_groom = df1[df["Easy To Groom"]>2]
easy_groom
# Out:
#       Dog Breed Group       Life Span  \
# 1    Mixed Breed Dogs  13 to 18 years
# 2      Companion Dogs  12 to 14 years
# 5        Working Dogs  10 to 12 years
# 8    Mixed Breed Dogs  10 to 12 years
# 9    Mixed Breed Dogs  10 to 13 years
# ..                ...             ...
# 386  Mixed Breed Dogs  12 to 15 years
# 387     Sporting Dogs  10 to 14 years
# 388    Companion Dogs  14 to 20 years
# 389      Working Dogs  10 to 12 years
# 390       Hybrid Dogs  10 to 15 years
#
#                                                 Height            Weight
# 1                                       6 to 12 inches    4 to 12 pounds
# 2                  9 to 11 inches tall at the shoulder     7 to 9 pounds
# 5                                      27 to 34 inches  75 to 140 pounds
# 8                                      16 to 23 inches   30 to 70 pounds
# 9                                      24 to 28 inches  75 to 120 pounds
# ...
